# %% [markdown]
# # Visuals - All charts embedded
# This notebook contains the generated charts embedded directly so they appear when opening the notebook.

# %% [markdown]
# ## Bar Chart
#
# <img src='data:image/png;base64,...' width='800'/>

# %% [markdown]
# ## Pie Chart
#
# <img src='data:image/png;base64,...' width='800'/>

# %% [markdown]
# ## Stacked Column Chart
#
# <img src='data:image/png;base64,...' width='800'/>

# %% [markdown]
# ## Scatter Plot
#
# <img src='data:image/png;base64,...' width='800'/>

# %% [markdown]
# ## Histogram
#
# <img src='data:image/png;base64,...' width='800'/>

# %% [markdown]
# ## Area Chart
#
# <img src='data:image/png;base64,...' width='800'/>

# %% [markdown]
# ## Boxplot
#
# <img src='data:image/png;base64,...' width='800'/>
